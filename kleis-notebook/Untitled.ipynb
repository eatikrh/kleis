# %%
example "test" {
    assert( 1 + 1 = 2)
}
# Out:
# ❌ test
#    Assertion failed: expected Const("2"), got Operation { name: "plus", args: [Const("1"), Const("1")], span: None }
#
# ❌ 0/1 examples passed (1 failed)

# %%
example "arithmetic" {
    assert(eval(1 + 1) = 2)
    assert(eval(2 * 3) = 6)
    assert(eval(10 - 4) = 6)
}
# Out:
# ✅ arithmetic
#
# ✅ 1 example passed
